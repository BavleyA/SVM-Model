# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv(r"E:\FCI\4th year\1\Machine Learning\Machine Learning\Machine Projects\SVM model with employee data set\Employee.csv")
df_original = df.copy()

# %% [markdown]
# Duplicate

# %%
df.duplicated().sum()
# Out:
# 1889

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      2778
# Female    1875
# Name: count, dtype: int64

# %%
px.histogram(data_frame=df , x = "Gender")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
# ...

# %%
df["Age"].value_counts()
# Out:
# Age
# 26    645
# 28    630
# 27    625
# 25    418
# 24    385
# 29    230
# 30    220
# 37    141
# 36    139
# 34    136
# 38    136
# 40    134
# 32    132
# 39    131
# 31    125
# 33    124
# 35    123
# 41     82
# 22     49
# 23     48
# Name: count, dtype: int64

# %%
px.histogram(data_frame=df , x = "Age")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
# ...

# %%
df["City"].value_counts()
# Out:
# City
# Bangalore    2228
# Pune         1268
# New Delhi    1157
# Name: count, dtype: int64

# %%
px.histogram(data_frame=df , x = "City")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
# ...

# %%
df["PaymentTier"].describe()
# Out:
# count    4653.000000
# mean        2.698259
# std         0.561435
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         3.000000
# Name: PaymentTier, dtype: float64

# %%
px.histogram(data_frame=df , x ="PaymentTier")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
# ...

# %%
px.box(data_frame=df , x ="PaymentTier")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
# ...

# %%
df[df["PaymentTier"] == df["PaymentTier"].max()]
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# 5     Bachelors         2016  Bangalore            3   22    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df["LeaveOrNot"].value_counts(normalize=True)
# Out:
# LeaveOrNot
# 0    0.656136
# 1    0.343864
# Name: proportion, dtype: float64

# %%
df.columns
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='object')

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# added dummy for analysis two string columns

# %%
df["duumy"] = 1

# %% [markdown]
# Number of male and females that Everbenched

# %%
pd.pivot_table(data=df , index = 'Gender' , columns = 'EverBenched' , values = 'duumy' , aggfunc=len)
# Out:
# EverBenched    No  Yes
# Gender
# Female       1696  179
# Male         2479  299

# %%
px.histogram(data_frame=df , x ="Gender" , color="EverBenched" ,barmode='group' , text_auto=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
# ...

# %% [markdown]
# Type of Education of Males and Females

# %%
pd.pivot_table(data=df , index = 'Gender' , columns = 'Education' , values = 'duumy' , aggfunc=len)
# Out:
# Education  Bachelors  Masters  PHD
# Gender
# Female          1435      371   69
# Male            2166      502  110

# %%
px.histogram(data_frame=df , x ="Gender" , color="Education" ,barmode='group' , text_auto=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\Users\paula\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
# ...

# %% [markdown]
# **Releationship between Gender and Experience**

# %%
df.groupby("Gender")["ExperienceInCurrentDomain"].mean()
# Out:
# Gender
# Female    2.889067
# Male      2.916847
# Name: ExperienceInCurrentDomain, dtype: float64

# %%
df.groupby("Gender")["PaymentTier"].mean()
# Out:
# Gender
# Female    2.537600
# Male      2.806695
# Name: PaymentTier, dtype: float64

# %%
(pd.pivot_table(data=df , index = 'Gender' , columns = 'Education' , values = 'duumy' , aggfunc=len)  * 100 ) / df.shape[0]
# Out:
# Education  Bachelors    Masters       PHD
# Gender
# Female     30.840318   7.973351  1.482914
# Male       46.550613  10.788738  2.364066

# %%
df.isnull().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# duumy                        0
# dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder , StandardScaler , LabelEncoder , RobustScaler
from sklearn.impute import SimpleImputer , KNNImputer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC 
from sklearn.naive_bayes import MultinomialNB , GaussianNB
from sklearn.model_selection import train_test_split , cross_validate
from sklearn.metrics import accuracy_score , recall_score , precision_score , f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
x = df.drop("LeaveOrNot" , axis = 1 )
y = df["LeaveOrNot"]

# %%
df.columns
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot', 'duumy'],
#       dtype='object')

# %%
df.drop(['duumy'] ,axis = 1 , inplace = True)

# %%
df.columns
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='object')

# %% [markdown]
# encode the labels in y (typically a list or array of categorical labels) into numeric values.
# fit_transform(y): This method does two things:
# .fit(): It learns the unique classes (categories) from the data y and assigns them an integer value.
# .transform(): It converts the original categorical labels into numeric values based on the encoding it learned.

# %%
y = LabelEncoder().fit_transform(y)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   duumy                      4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %% [markdown]
# **Num_Columns: Contains all columns with numerical data types (like int or float).Cat_Columns: Contains all columns with object data types (categorical features).The .select_dtypes() method helps in separating columns based on their data type.**

# %% [markdown]
# select all colums the data frames x that has numerical data and categorigal data

# %%
Num_Columns = x.select_dtypes(include="number")
Cat_Columns = x.select_dtypes(include="object_")

# %% [markdown]
# back to

# %% [markdown]
# create pipeline for categorical data

# %%
Cat_Steps = list()
Cat_Steps.append(("Cat_Imputer" , SimpleImputer(strategy='most_frequent')))
Cat_Steps.append(("Cat_Encoder" , OneHotEncoder(sparse_output=False , drop='first')))
Cat_Pipeline = Pipeline(steps= Cat_Steps)

# %%
Num_Steps = list()
Num_Steps.append(("Num_Imputer" , KNNImputer()))
Num_Steps.append(("Scaler" , StandardScaler()))
Num_Pipeline = Pipeline(steps=Num_Steps)

# %% [markdown]
# reamainder back to

# %% [markdown]
# apply the transformer for

# %%
Transformer = ColumnTransformer(transformers=[('Num' , Num_Pipeline , Num_Columns.columns) , 
                                              ('Cat' , Cat_Pipeline , Cat_Columns.columns) ] , remainder='passthrough')

# %%
steps = list()
steps.append(("Preprocessing" , Transformer))
steps.append(("Model" , LogisticRegression()))
pipeline = Pipeline(steps=steps)

# %%
results = cross_validate(pipeline , x , y , scoring="accuracy"  ,cv = 5 , return_train_score=True)

# %%
results["train_score"].mean()
# Out:
# 0.7358151970201933

# %%
results["test_score"].mean()
# Out:
# 0.7324257648730121

# %%
models = list()
models.append(("SVM" , SVC()))

# %%
steps = list()
steps.append(("Preprocessing" , Transformer))
steps.append(("SVM" , SVC()))
pipeline = Pipeline(steps = steps)
scores = cross_validate(pipeline , x , y , scoring="accuracy"  ,cv = 5 , return_train_score=True , return_estimator=True)
print("Train_accuracy" , scores["train_score"].mean() )
print("-" * 20)
print("Test_accuracy" , scores["test_score"].mean())
print("-" * 20)
print("\n")
# Out:
# Train_accuracy 0.8553083111893003
# --------------------
# Test_accuracy 0.8411769053971334
# --------------------

# %%
pipeline["SVM"].get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %% [markdown]
# try all params on the model

# %%
from sklearn.model_selection import GridSearchCV
params = [
        {'SVM__C':[0.5,1,2,3,5], 'SVM__kernel':['linear', 'sigmoid', 'poly']},
        {'SVM__C':[0.5,1,2,3,5], 'SVM__kernel':['rbf'], 'SVM__gamma':[0.5, 0.6, 0.7, 0.1, 0.01, 0.05,"scale"]},
        {'SVM__C':[0.5,1,2,3,5], 'SVM__kernel':['poly'] , "SVM__degree" :[2,3,4,5]},
         ]

# %%
steps = list()
steps.append(("Preprocessing" , Transformer))
steps.append(("SVM" , SVC()))
pipeline = Pipeline(steps = steps)

# %%
grid_search = GridSearchCV(estimator=pipeline,
                           param_grid=params,
                           scoring='accuracy',
                           cv=5, n_jobs=-1,return_train_score=True)
grid_search.fit(x, y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Preprocessing',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('Num',
#                                                                          Pipeline(steps=[('Num_Imputer',
#                                                                                           KNNImputer()),
#                                                                                          ('Scaler',
#                                                                                           StandardScaler())]),
#                                                                          Index(['JoiningYear', 'PaymentTier', 'Age', 'ExperienceInCurrentDomain',
#        'duumy'],
#       dtype='object')),
#                                                                         ('Cat',
# ...

# %%
print(grid_search)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Preprocessing',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('Num',
#                                                                          Pipeline(steps=[('Num_Imputer',
#                                                                                           KNNImputer()),
#                                                                                          ('Scaler',
#                                                                                           StandardScaler())]),
#                                                                          Index(['JoiningYear', 'PaymentTier', 'Age', 'ExperienceInCurrentDomain',
#        'duumy'],
#       dtype='object')),
#                                                                         ('Cat',
# ...

# %%
grid_search.cv_results_["mean_test_score"].mean()
# Out:
# 0.7973349535788121

# %%
grid_search.cv_results_["mean_train_score"].mean()
# Out:
# 0.8171839443527701

# %%
grid_search.best_estimator_
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Num',
#                                                   Pipeline(steps=[('Num_Imputer',
#                                                                    KNNImputer()),
#                                                                   ('Scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['JoiningYear', 'PaymentTier', 'Age', 'ExperienceInCurrentDomain',
#        'duumy'],
#       dtype='object')),
#                                                  ('Cat',
#                                                   Pipeline(steps=[('Cat_Imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
pipeline.fit(x,y)
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Num',
#                                                   Pipeline(steps=[('Num_Imputer',
#                                                                    KNNImputer()),
#                                                                   ('Scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['JoiningYear', 'PaymentTier', 'Age', 'ExperienceInCurrentDomain',
#        'duumy'],
#       dtype='object')),
#                                                  ('Cat',
#                                                   Pipeline(steps=[('Cat_Imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
import joblib

# %%
joblib.dump(pipeline , "SVM model.pkl")
joblib.dump(x.columns,"Inputs.pkl")
# Out:
# ['Inputs.pkl']

# %%
import joblib
import pandas as pd
import numpy as np
import streamlit as st

Model = joblib.load(r"E:\FCI\4th year\1\Machine Learning\Machine Learning\Machine Projects\SVM model with employee data set\SVM model.pkl")
Inputs = joblib.load(r"E:\FCI\4th year\1\Machine Learning\Machine Learning\Machine Projects\SVM model with employee data set\Inputs.pkl")

def prediction(Education,JoiningYear,City,PaymentTier,Age,Gender,EverBenched,ExperienceInCurrentDomain):
    df = pd.DataFrame(columns=Inputs)
    df.at[0,"Education"] = Education
    df.at[0,"JoiningYear"] = JoiningYear
    df.at[0,"City"] = City
    df.at[0,"PaymentTier"] = PaymentTier
    df.at[0,"Age"] = Age
    df.at[0,"Gender"] = Gender
    df.at[0,"EverBenched"] = EverBenched
    df.at[0,"ExperienceInCurrentDomain"] = ExperienceInCurrentDomain
    result = Model.predict(df)[0]
    return result

def Main():
    st.title("Leave or Not Leave My Lovely Company Prediction")
    Education = st.selectbox("Education",['Bachelors', 'Masters' , 'PHD'])
    JoiningYear = st.slider("JoiningYear",min_value=2012.0 , max_value=2018.0 , step=1.0,value = 2012.0)
    City = st.selectbox("City",[ 'Bangalore',  'Pune',  'New Delhi'])
    PaymentTier = st.selectbox("PaymentTier",[ '1',  '2',  '3'])
    Age = st.slider("Age",min_value=20.0 , max_value=60.0 , step=1.0,value = 20.0)
    Gender = st.selectbox("Gender",['Male', 'Female'])
    EverBenched = st.selectbox("EverBenched",['Yes','No'])
    ExperienceInCurrentDomain = st.slider("ExperienceInCurrentDomain",min_value=0.0 , max_value=7.0 , step=1.0,value = 0.0)
    
    
    if st.button("Predict"):
        result = prediction(Education,JoiningYear ,City,PaymentTier,Age,Gender,EverBenched,ExperienceInCurrentDomain)
        list_result = ["Not Leave" , "Leave"]
        st.text(f"Your Employee Will {list_result[result]}")
Main()
# Out:
# 2024-12-04 20:44:53.009 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-04 20:44:53.331
# ...
#   command:
#
#     streamlit run C:\Users\paula\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-12-04 20:44:53.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-04 20:44:53.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-04 20:44:53.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-04 20:44:53.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-04 20:44:53.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
 # Education	 JoiningYear City	PaymentTier	Age	Gender	EverBenched	ExperienceInCurrentDomain	LeaveOrNot
# Bangalore Pune New Delhi
